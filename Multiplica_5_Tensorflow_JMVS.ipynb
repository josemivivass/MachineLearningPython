# %% [markdown]
# ---
# ---
#
# #Red Neuronal multiplicacion de 5 Tensorflow
#
# ---
# ---

# %%
#Importamos Librerías
import tensorflow as tf
import numpy as np

# %%
# Datos de multiplicar del 5
entrada=np.array([[5,0],[5,1],[5,2],[5,3],[5,4],[5,5],[5,6],[5,7],[5,8],[5,9],[5,10]], "int64")

#salida = tf.constant([[0], [5], [10], [15],[20], [25], [30], [35],[40], [45], [50]], dtype=tf.int64)
salida = np.array([0,5,10,15,20,25,30,35,40,45,50], "int64")

# %%
# Definición del modelo
model = tf.keras.Sequential()
#modelo con 1 neurona y dos entradas
model.add(tf.keras.layers.Dense(1,  input_shape=(2,)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilación del modelo
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])

# %%
# Entrenamiento del modelo
historial=model.fit(entrada, salida, epochs=2000, verbose=0)

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(historial.history["loss"])

# %%
# Utiliza el modelo para hacer predicciones
x_test = np.array([[5,11],[5,12],[5,13],[5,14]])
y_test = np.array([55,60,65,70])
y_pred = model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %%
y_pred
# Out:
# array([[54.999996],
#        [59.999992],
#        [64.99999 ],
#        [69.99999 ]], dtype=float32)

# %%
# Imprime los resultados
print('Tabla de multiplicar de 5:')
for i in range(len(x_test)):
    print('{} x 5 = {} (predicción: {})'.format(x_test[i], y_test[i], int(y_pred[i])))
# Out:
# Tabla de multiplicar de 5:
# [ 5 11] x 5 = 55 (predicción: 54)
# [ 5 12] x 5 = 60 (predicción: 59)
# [ 5 13] x 5 = 65 (predicción: 64)
# [ 5 14] x 5 = 70 (predicción: 69)
# /tmp/ipykernel_16480/3954413593.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('{} x 5 = {} (predicción: {})'.format(x_test[i], y_test[i], int(y_pred[i])))

# %%
aa = model.predict(np.array([[5,23]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
aa
# Out:
# array([[114.99999]], dtype=float32)

# %%
aa.round()
# Out:
# array([[115.]], dtype=float32)

# %%
model.save('multi5tensorflow.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
